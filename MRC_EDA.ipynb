# %% [markdown]
# # MRC 대회 Dataset EDA

# %% [markdown]
# ## 0. 개요

# %% [markdown]
# * __실험 제목__ : 대회 데이터셋 EDA
# * __작성자__ : 김준석_T3055
# * __실험 일시__ : 22.05.04 ~ 22.05.04(1일간)
#
# * __실험 목적__ : 데이터셋을 분석하여 데이터셋의 오류점이나 보완할 점을 찾는다. 데이터셋의 특징이나 경향성을 파악한다.
# * __관련 근거__ : 없음
# * __실험 WorkFlow__ : 데이터셋 오류 및 이상치 탐지 -> 데이터 시각화등을 통한 데이터셋의 특징확인
# * __기타__ : Jupyter Notebook 사용하여 실험

# %% [markdown]
# ## 1. Dataset 불러오기

# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import random
from datasets import load_from_disk
import json
from tqdm.notebook import tqdm

#arrow 파일
dataset = load_from_disk("/opt/ml/input/data/train_dataset")
test_dataset = load_from_disk("/opt/ml/input/data/test_dataset")

#DatasetDict에서 가져오기
train_dataset = dataset["train"]
valid_dataset = dataset["validation"]
test_dataset = test_dataset['validation']

# DataFrame
train_df = pd.DataFrame(train_dataset)
valid_df = pd.DataFrame(valid_dataset)
test_df = pd.DataFrame(test_dataset)

# Retrieval
wiki_corpus = pd.read_json("/opt/ml/input/data/wikipedia_documents.json").transpose()
wiki_corpus['text_length'] = int()
for i in tqdm(range(len(wiki_corpus))) : 
    wiki_corpus['text_length'][i] = len(wiki_corpus['text'][i])
# Out:
# ...
# /tmp/ipykernel_2574/935361674.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wiki_corpus['text_length'][i] = len(wiki_corpus['text'][i])

# %% [markdown]
# ### 1-1. 데이터셋 확인
# * Train Dataset(3952개) & Vaildation Dataset(240개)은 'title(주제)', 'context(문장)', 'question(질문)', 'id', 'answer(답의 위치, 답)', 'document_id', '\_\_index_level_0\_\_' 으로 구성됨.
# * Test Dataset(600개)은 'question(질문)', 'id' 으로 구성됨.
# * wiki_corpus(60613)는 'text(문장)', 'corpus_source(출처)', 'url', 'domain', 'title(주제)', 'author', 'html', 'document_id', 'text_length' 으로 구성됨.

# %%
train_df
# Out:
#                   title                                            context  \
# 0                 미국 상원  미국 상의원 또는 미국 상원(United States Senate)은 양원제인 미국...
# 1                인사조직관리  '근대적 경영학' 또는 '고전적 경영학'에서 현대적 경영학으로 전환되는 시기는 19...
# 2                   강희제  강희제는 강화된 황권으로 거의 황제 중심의 독단적으로 나라를 이끌어 갔기에 자칫 전...
# 3                금동삼존불감  불상을 모시기 위해 나무나 돌, 쇠 등을 깎아 일반적인 건축물보다 작은 규모로 만든...
# 4               계사명 사리구  동아대학교박물관에서 소장하고 있는 계사명 사리구는 총 4개의 용기로 구성된 조선후기...
# ...                 ...                                                ...
# 3947            이오 (위성)  이오의 산\n이오의 산 목록\n 이오에는 100~150개의 산이 있다. 이들 산의 ...
# 3948            내니 다이어리  애니의 고군분투 뉴욕 입성기!!\n\n인류학자가 꿈인 21살 소녀 '애니(스칼렛 요...
# 3949        빈 필하모니 관현악단  1842년에 작곡가이자 지휘자인 오토 니콜라이가 빈 궁정 오페라극장 소속 관현악단을...
# 3950                드래곤  원어는 고대 그리스어까지 거슬러 올라간다. 영어 문헌에 이 말이 나타나기 시작한 것...
# 3951  2011년 함부르크 주의회 선거  2008년 2월 28일 실시된 2008년 함부르크 주의회 선거에서 기민련은 과반수 ...
#
#                                      question            id  \
# ...

# %%
valid_df
# Out:
#         title                                            context  \
# 0         전효숙  순천여자고등학교 졸업, 1973년 이화여자대학교를 졸업하고 1975년 제17회 사법...
# 1       스토우빌선  요크 카운티 동쪽에 처음으로 여객 열차 운행이 시작한 시점은 1868년 토론토 & ...
# 2          촐라  촐라 정부\n 촐라의 정부 체제는 전제군주제였으며,2001 촐라의 군주는 절대적인 ...
# 3       백조 기사  프랑스의 십자군 무훈시는 1099년 예루살렘 왕국의 통치자가 된 고드프루아 드 부용...
# 4       탈관료제화  탈관료제화는 현대사회에서 관료제 성격이 약화되는 현상이다. 현대사회에서 관료제는 약...
# ..        ...                                                ...
# 235  전단 (제나라)  연나라 군대의 사령관이 악의에서 기겁으로 교체되자, 전단은 스스로 신령의 계시를 받...
# 236        티칼  현재 우리가 볼 수 있는 티칼의 모습은 펜실베이니아 대학교와 과테말라 정부의 협조 ...
# 237       윤치호  1940년 5월 1일 오전 창씨개명에 비협조적이라는 이유로 조선총독부 경무국에서 소...
# 238      신잉카국  빌카밤바 지역은 파차쿠티 황제 때 부터 잉카 제국에 속해있던 지역이었다. 스페인 군...
# 239      레닌주의  사회주의 혁명은 오로지 선진노동자계급에 기초한 계급투쟁으로서 이루어질 수 있다고 주...
#
#                                  question            id  \
# 0          처음으로 부실 경영인에 대한 보상 선고를 받은 회사는?  mrc-0-003264
# 1    스카버러 남쪽과 코보콘그 마을의 철도 노선이 처음 연장된 연도는?  mrc-0-004762
# ...

# %%
test_df
# Out:
#                                          question            id
# 0                           유령'은 어느 행성에서 지구로 왔는가?  mrc-1-000653
# 1                 용병회사의 경기가 좋아진 것은 무엇이 끝난 이후부터인가?  mrc-1-001113
# 2         돌푸스에게 불특정 기간동안 하원이 잠시 쉬는 것을 건의 받았던 인물은?  mrc-0-002191
# 3            마오리언어와 영어, 뉴질랜드 수화를 공식 언어로 사용하는 나라는?  mrc-0-003951
# 4                      디엔비엔푸 전투에서 보응우옌잡이 상대한 국가는?  mrc-1-001272
# ..                                            ...           ...
# 595                         타입 2 가이아 메모리을 만든 집단은?  mrc-0-002989
# 596            장면이 정치보복에 반대하는 입장에서 처벌을 원치 않은 대상은?  mrc-0-001804
# 597  콜드게임 중 어떠한 계기로 인해 잠시 중단된 뒤, 익일에 게임이 진행되는 것은?  mrc-0-003411
# 598                            제2캐나다기갑여단이 상륙한 곳은?  mrc-0-003436
# 599                     구립운석을 이루는 물질 중 널리 알려진 것은?  mrc-0-002605
#
# [600 rows x 2 columns]

# %%
wiki_corpus
# Out:
#                                                     text corpus_source   url  \
# 0      이 문서는 나라 목록이며, 전 세계 206개 나라의 각 현황과 주권 승인 정보를 개...         위키피디아  TODO
# 1      이 목록에 실린 국가 기준은 1933년 몬테비데오 협약 1장을 참고로 하였다. 협정...         위키피디아  TODO
# 2      현 서울특별시 종로구 서린동 (구 일제 강점기 경기도 경성부 서린정) 출신이다. 친...         위키피디아  TODO
# 3      아오조라 문고(靑空文庫, あおぞらぶんこ|아오조라 분고)는 ‘일본어판 구텐베르크 프로...         위키피디아  TODO
# 4      저자 사망 이후 50년이 지나 저작권이 소멸한 메이지 시대부터 쇼와 시대 초기까지의...         위키피디아  TODO
# ...                                                  ...           ...   ...
# 60608  오키나와 현립 박물관·미술관( , Okinawa Prefectural Museum ...         위키피디아  None
# 60609  1936년 7월, 오키나와현 교육위원회 부설 향토 박물관(沖縄県教育会附設郷土博物館)...         위키피디아  None
# 60610  박물관은 개관 10주년이되는 2017년에 관의 애칭 및 마스코트를 일반인에게 공모했...         위키피디아  None
# 60611  단결권 및 단체교섭권 협약(Right to Organise and Collectiv...         위키피디아  None
# 60612  이 협약은 부당노동행위 제도를 규율하고 있다. 협약 제1조에서 반노동조합 차별행위로...         위키피디아  None
#
# ...

# %% [markdown]
# ### 1-2. 데이터셋 형태 변경
# * 'answers' column의 형태를 변경하여 Dataframe에 좀 더 쉽게 접근할 수 있도록 한다.

# %%
df_list = [train_df, valid_df]

# ex) {'answer_start': [284], 'text': ['한보철강']}	
start = len("{'answer_start': [")
split_text = "], 'text': ["
end = len("]}")
flag = 0
for df in df_list : 
    flag += 1
    answer_start = []
    answer = []
    
    context_length = []
    question_length = []
    answer_length = []
    
    for idx, ans in enumerate(df['answers']) : 
        temp = str(ans)[start: -end].split(split_text)
        answer_start.append(int(temp[0]))
        answer.append(temp[1][1:-1])
        
    for i in range(len(df)) : 
        temp_context_length = len(df['context'][i])
        temp_question_length = len(df['question'][i])
        temp_answer_length = len(answer[i])
        
        context_length.append(temp_context_length)
        question_length.append(temp_question_length)
        answer_length.append(temp_answer_length)
        
    temp_df = pd.DataFrame({'title': df['title'], 
                                    'context' : df['context'], 
                                    'context_length' : context_length,
                                    'question': df['question'], 
                                    'question_length' : question_length,
                                    'answer': answer,
                                    'answer_start': answer_start, 
                                    'answer_length' : answer_length,
                                    'document_id': df['document_id'], 
                                    '__index_level_0__': df['__index_level_0__'],})
    
    if flag == 1 : 
        preprocessed_train_df  = temp_df
    elif flag == 2 :
        preprocessed_valid_df = temp_df

# %%
preprocessed_train_df
# Out:
#                   title                                            context  \
# 0                 미국 상원  미국 상의원 또는 미국 상원(United States Senate)은 양원제인 미국...
# 1                인사조직관리  '근대적 경영학' 또는 '고전적 경영학'에서 현대적 경영학으로 전환되는 시기는 19...
# 2                   강희제  강희제는 강화된 황권으로 거의 황제 중심의 독단적으로 나라를 이끌어 갔기에 자칫 전...
# 3                금동삼존불감  불상을 모시기 위해 나무나 돌, 쇠 등을 깎아 일반적인 건축물보다 작은 규모로 만든...
# 4               계사명 사리구  동아대학교박물관에서 소장하고 있는 계사명 사리구는 총 4개의 용기로 구성된 조선후기...
# ...                 ...                                                ...
# 3947            이오 (위성)  이오의 산\n이오의 산 목록\n 이오에는 100~150개의 산이 있다. 이들 산의 ...
# 3948            내니 다이어리  애니의 고군분투 뉴욕 입성기!!\n\n인류학자가 꿈인 21살 소녀 '애니(스칼렛 요...
# 3949        빈 필하모니 관현악단  1842년에 작곡가이자 지휘자인 오토 니콜라이가 빈 궁정 오페라극장 소속 관현악단을...
# 3950                드래곤  원어는 고대 그리스어까지 거슬러 올라간다. 영어 문헌에 이 말이 나타나기 시작한 것...
# 3951  2011년 함부르크 주의회 선거  2008년 2월 28일 실시된 2008년 함부르크 주의회 선거에서 기민련은 과반수 ...
#
#       context_length                                 question  \
# ...

# %%
preprocessed_valid_df
# Out:
#         title                                            context  \
# 0         전효숙  순천여자고등학교 졸업, 1973년 이화여자대학교를 졸업하고 1975년 제17회 사법...
# 1       스토우빌선  요크 카운티 동쪽에 처음으로 여객 열차 운행이 시작한 시점은 1868년 토론토 & ...
# 2          촐라  촐라 정부\n 촐라의 정부 체제는 전제군주제였으며,2001 촐라의 군주는 절대적인 ...
# 3       백조 기사  프랑스의 십자군 무훈시는 1099년 예루살렘 왕국의 통치자가 된 고드프루아 드 부용...
# 4       탈관료제화  탈관료제화는 현대사회에서 관료제 성격이 약화되는 현상이다. 현대사회에서 관료제는 약...
# ..        ...                                                ...
# 235  전단 (제나라)  연나라 군대의 사령관이 악의에서 기겁으로 교체되자, 전단은 스스로 신령의 계시를 받...
# 236        티칼  현재 우리가 볼 수 있는 티칼의 모습은 펜실베이니아 대학교와 과테말라 정부의 협조 ...
# 237       윤치호  1940년 5월 1일 오전 창씨개명에 비협조적이라는 이유로 조선총독부 경무국에서 소...
# 238      신잉카국  빌카밤바 지역은 파차쿠티 황제 때 부터 잉카 제국에 속해있던 지역이었다. 스페인 군...
# 239      레닌주의  사회주의 혁명은 오로지 선진노동자계급에 기초한 계급투쟁으로서 이루어질 수 있다고 주...
#
#      context_length                              question  question_length  \
# 0               625        처음으로 부실 경영인에 대한 보상 선고를 받은 회사는?               30
# ...

# %% [markdown]
# ## 2. Dataset의 기본 정보 살펴보기

# %% [markdown]
# ### 2-1. Train Dataset 기본 정보
#
# 1. '윤치호'라는 주제의 문장이 43개나 발견되었다.
# 2. 최대로 중복된 문장은 4번 중복된 문장이다.
# 3. 어떠한 질문도 중복되지 않았다.
# 4. 질문의 평균 길이는 약 29 이다.(최소 8 ~ 최대 78)
# 5. '프랑스'가 정답인 질문은 15개나 존재한다.
# 6. 정답의 평균 길이는 약 6 이다.(최소 1 ~ 최대 83)
# 5. 3952개 문장 중 0번 위치(시작부터 답이존재)인 문장은 69개(1.7%)이다.

# %%
preprocessed_train_df.describe(include='all')
# Out:
#        title                                            context  \
# count   3952                                               3952
# unique  2716                                               3340
# top      윤치호  그러나 한편으로는 미국 사회의 인종차별주의적, 흑인을 차별하는 태도를 목격하면서 백...
# freq      43                                                  4
# mean     NaN                                                NaN
# std      NaN                                                NaN
# min      NaN                                                NaN
# 25%      NaN                                                NaN
# 50%      NaN                                                NaN
# 75%      NaN                                                NaN
# max      NaN                                                NaN
#
#         context_length                          question  question_length  \
# count      3952.000000                              3952      3952.000000
# ...

# %% [markdown]
# ### 2-2. Validation Dataset 기본 정보
#
# 1. '교황 비오 11세'라는 주제의 문장이 2개 발견되었다.
# 2. 최대로 중복된 문장은 2번 중복된 문장이다.
# 3. 어떠한 질문도 중복되지 않았다.
# 4. 질문의 평균 길이는 약 29 이다.(최소 9 ~ 최대 59)
# 5. 어떠한 정답도 중복되지 않았다.
# 6. 정답의 평균 길이는 약 7 이다.(최소 1 ~ 최대 64)
# 7. 240개 문장 중 0번 위치(시작부터 답이존재)인 문장은 5개(2.1%)이다.

# %%
preprocessed_valid_df.describe(include='all')
# Out:
#             title                                            context  \
# count         240                                                240
# unique        228                                                235
# top     교황 비오 11세  현재 우리가 볼 수 있는 티칼의 모습은 펜실베이니아 대학교와 과테말라 정부의 협조 ...
# freq            2                                                  2
# mean          NaN                                                NaN
# std           NaN                                                NaN
# min           NaN                                                NaN
# 25%           NaN                                                NaN
# 50%           NaN                                                NaN
# 75%           NaN                                                NaN
# max           NaN                                                NaN
#
#         context_length                        question  question_length  \
# ...

# %% [markdown]
# ## 3. Dataset의 분포 알아보기

# %% [markdown]
# ### 3-1. title length 분포

# %%
# title length
train_title_length = [len(e) for e in preprocessed_train_df['title']]
vaild_title_length = [len(e) for e in preprocessed_valid_df['title']]
fix, ax = plt.subplots(ncols=2, figsize=(15,5))
sns.histplot(train_title_length, ax=ax[0]).set_title("preprocessed_train_df : context_length")
sns.histplot(vaild_title_length, ax=ax[1]).set_title("preprocessed_valid_df : context_length");

# %% [markdown]
# ### 3-2. context length 분포

# %%
# context length
fix, ax = plt.subplots(ncols=2, figsize=(15,5))
sns.histplot(preprocessed_train_df['context_length'], ax=ax[0]).set_title("preprocessed_train_df : context_length")
sns.histplot(preprocessed_valid_df['context_length'], ax=ax[1]).set_title("preprocessed_valid_df : context_length");

# %% [markdown]
# ### 3-3. question length 분포

# %%
# question length
fix, ax = plt.subplots(ncols=2, figsize=(15,5))
sns.histplot(preprocessed_train_df['question_length'], ax=ax[0]).set_title("preprocessed_train_df : question_length")
sns.histplot(preprocessed_valid_df['question_length'], ax=ax[1]).set_title("preprocessed_valid_df : question_length");

# %% [markdown]
# ### 3-4. answer length 분포

# %%
# answer length
fix, ax = plt.subplots(ncols=2, figsize=(15,5))
sns.histplot(preprocessed_train_df['answer_length'], ax=ax[0]).set_title("preprocessed_train_df : answer_length")
sns.histplot(preprocessed_valid_df['answer_length'], ax=ax[1]).set_title("preprocessed_valid_df : answer_length");

# %% [markdown]
# ### 3-5. answer length 분포

# %%
# answer start
fix, ax = plt.subplots(ncols=2, figsize=(15,5))
sns.histplot(preprocessed_train_df['answer_start'], ax=ax[0]).set_title("preprocessed_train_df : answer_start")
sns.histplot(preprocessed_valid_df['answer_start'], ax=ax[1]).set_title("preprocessed_valid_df : answer_start");

# %% [markdown]
# ## 4. 잘못된 데이터 찾기

# %% [markdown]
# ### 4-1. question에서 물음표가 없는 것?

# %%
for i in range(len(preprocessed_train_df)) : 
    if preprocessed_train_df['question'][i][-1] != '?' :
        print(f"{i}번째 질문 : {preprocessed_train_df['question'][i]}")
# Out:
# 295번째 질문 : 피아니스트이자 출판업을 하는 베토벤의 친구는
# 3170번째 질문 : 이고르 댜틀로프가 이끄는 모임에서 가장 먼저 빠진 사람은?-

# %%
# 없음
for i in range(len(preprocessed_valid_df)) : 
    if preprocessed_valid_df['question'][i][-1] != '?' :
        print(f"{i}번째 질문 : {preprocessed_valid_df['question'][i]}")

# %% [markdown]
# ### 4-2. answer이 context 내부에 없는 것?

# %%
for i in range(len(preprocessed_train_df)) : 
    if preprocessed_train_df['answer'][i] not in preprocessed_train_df['context'][i] :
        print(f"{i}번째 문장 : 답 = {preprocessed_train_df['answer'][i]} | 문장 = {preprocessed_train_df['context'][i]}")

# 최근의 반도의 경제사범 \xad국민의 신경제 윤리의 파악을 위하여\xad
# 최근의 반도의 경제사범 ­국민의 신경제 윤리의 파악을 위하여­
        
# 답에 이상한 것들이 포함되어 있는 경우를 지워주어야 하는가?
# ex) \xad \n
# Out:
# 544번째 문장 : 답 = 최근의 반도의 경제사범 \xad국민의 신경제 윤리의 파악을 위하여\xad | 문장 = 경상북도 출신으로 1935년에 경성제국대학 법문학부 법학과를 졸업했다. 1938년에 경성지방법원 및 경성지방법원검사국 사법관시보가 된 것을 시작으로 법조계에서 근무를 시작했다.\n\n1939년에는 경성지방법원 검사대리가 되었고, 1940년에 예비검사를 거쳐 그해부터 1943년까지 조선총독부 검사로 근무했다. 강중인은 경제담당 검사로 일하면서 태평양 전쟁 중 시국 연설과 기고로 사회 활동을 병행했다. \n\n1942년에 조선임전보국단 주최로 경성중앙방송국에서 저명 인사의 시국연설을 방송했을 때, 〈필승사상전(必勝思想戰)〉이라는 제목으로 연설한 일이 있다.\n\n《삼천리》에 〈최근의 반도의 경제사범 ­국민의 신경제 윤리의 파악을 위하여­〉라는 글을 기고하기도 했다. 이 글에서는 경제사범을 "미증유의 국난"을 돌파해 "대동아를 건설하는" 국가적으로 중대한 순간에 사리사욕에만 눈이 먼 집단으로 묘사하고, 이들은 국민의 일대수치이므로 엄벌주의로 대처할 것이라 경고했다. 또한 관민이 일체가 되어 "일사보국의 성을 다함"으로써 성업을 어서 완수해야 한다는 주장을 폈다.\n\n1943년에 대전지방법원 검사로 자리를 옮겨 일본 제국이 태평양 전쟁에서 패망할 때까지 근무했다. \n\n미군정 하의 서울에서 변호사를 개업하면서 좌익 운동에 뛰어들었다. 좌익 법조인 모임인 법학자동맹과 남조선로동당에 가입해 활동했다. 강중인이 남로당에 가입하게 된 동기는 후에 법정에서 다음과 같이 밝힌 바 있다. \n\n일정(日政) 당시에는 내가 내 한 몸을 구하기에 여력이 없었습니다. 8·15 해방을 맞이하자 피고는 이때야 깨달은 바가 있었습니다. 이는 다름이 아닙니다. 내가 어찌하면 국가와 민족을 위하여 일할 수 있을까 함이었습니다. 해외에서 국가와 민족을 위하여 투쟁하던 위대한 애국자들이 해방된 조국을 찾아 들어옴을 볼 때 무어라고 표현할 수 없는 느낌이 있었습니다. 그 후 피고는
# ...

# %%
# 없음
for i in range(len(preprocessed_valid_df)) : 
    if preprocessed_valid_df['answer'][i] not in preprocessed_valid_df['context'][i] :
        print(f"{i}번째 문장 : 답 = {preprocessed_valid_df['answer'][i]} | 문장 = {preprocessed_valid_df['context'][i]}")

# %% [markdown]
# ### 4-3. answer start의 위치가 올바르지 않은 것?

# %%
# 없음
for i in range(len(preprocessed_train_df)) : 
    if preprocessed_train_df['answer'][i][0] != preprocessed_train_df['context'][i][preprocessed_train_df['answer_start'][i]] :
        print(f"{i}번째 문장 : answer = {preprocessed_train_df['answer'][i]} | 틀린 위치 = {preprocessed_train_df['answer_start'][i]} | 진짜 위치 = {preprocessed_train_df['context'][i].find(preprocessed_train_df['answer'][i])} | 문장 = {preprocessed_train_df['context'][i]}")

# %%
for i in range(len(preprocessed_valid_df)) : 
    if preprocessed_valid_df['answer'][i][0] != preprocessed_valid_df['context'][i][preprocessed_valid_df['answer_start'][i]] :
        print(f"{i}번째 문장 : answer = {preprocessed_valid_df['answer'][i]} | 틀린 위치 = {preprocessed_valid_df['answer_start'][i]} | 진짜 위치 = {preprocessed_valid_df['context'][i].find(preprocessed_valid_df['answer'][i])} | 문장 = {preprocessed_valid_df['context'][i]}")

# %% [markdown]
# ## 5. 단순 중복 데이터 찾기

# %% [markdown]
# ### 5-1. title 중복

# %%
preprocessed_train_df[preprocessed_train_df.duplicated(['title'],keep=False)].sort_values('title')
# Out:
#              title                                            context  \
# 978    1875년 페이지 법  미국으로 온 최초의 중국인 이민자들은 압도적으로 남성이 다수였다. 그들 대다수가 캘...
# 2604   1875년 페이지 법  미국으로 온 최초의 중국인 이민자들은 압도적으로 남성이 다수였다. 그들 대다수가 캘...
# 2865  1952년 이집트 혁명  한편 수에즈 운하에 주둔하고 있던 영국군은 해당 지역의 반영 봉기를 진압할 준비를 ...
# 2352  1952년 이집트 혁명  1882년 영국군은 앵글로-이집트 전쟁을 통하여 이집트 정치에 개입하기 시작하였다....
# 949   1952년 이집트 혁명  1953년 6월 나기브는 공화정을 선포하여 군주제와 귀족 제도를 폐지하였고 이집트 ...
# ...            ...                                                ...
# 2730      히지카타 도시조  10월 20일, 에조치 와시노키에 상륙 후 도시조는 문도군 총독이 되어서 고료카쿠(...
# 626      히페리온 (위성)  보이저 2호는 토성을 지나가면서 많은 사진들을 전송했지만, 히페리온과는 멀리 떨어진...
# 2243     히페리온 (위성)  보이저 2호는 토성을 지나가면서 많은 사진들을 전송했지만, 히페리온과는 멀리 떨어진...
# 1449             힐  힐은 전쟁중에 논쟁을 피하지 못했다. 병약한 체질이라서 여러 번 병치레를 했기에, ...
# 389              힐  힐은 전쟁중에 논쟁을 피하지 못했다. 병약한 체질이라서 여러 번 병치레를 했기에, ...
#
#       context_length                                question  question_length  \
# ...

# %%
preprocessed_valid_df[preprocessed_valid_df.duplicated(['title'],keep=False)].sort_values('title')
# Out:
#          title                                            context  \
# 61   교황 비오 11세  오랫동안 학문에 몸 담아왔던 그는 교회 내에서 급속도로 출세가도를 달리기 시작했다....
# 66   교황 비오 11세  비오 11세는 이리 오랫동안 질병을 앓았으며, 1938년 11월 25일 몇 시간에 ...
# 56         김준연  1947년 12월 김성수가 한민당 당수가 되면서 그는 한민당 부당수로 선임되었다. ...
# 132        김준연  6세 때부터 월출산을 보며 서당에 나가 한문을 배웠다 마을 서당에서 공부하다가 형편...
# 118      나치 독일  1941년 6월 22일에는 독일이 독소불가침 조약을 깨고 380만 명의 추축국 군대...
# 145      나치 독일  1919년부터 1933년까지 독일은 제 1차 세계대전 이후 세워진 바이마르 공화국이...
# 20   데카메론의 줄거리  이야기에서 성 프란체스코 수도회의 수도사 라고만 언급되나, 조반니 빌라니의 연대기와...
# 190  데카메론의 줄거리  안드레우치오 디 피에트로는 하룻밤 사이에 온갖 우여곡절을 겪은 사람이다. 안드레우치...
# 239       레닌주의  사회주의 혁명은 오로지 선진노동자계급에 기초한 계급투쟁으로서 이루어질 수 있다고 주...
# 32        레닌주의  레닌주의에서 협동조합 개념을 이해할 때 주의해야 할 것은, 레닌이 주장하는 것은 자...
# 126      로마 군단  기원전 104년 이래로, 각 군단들은 아퀼라 (독수리)를 군단의 상징으로 사용했다....
# 37       로마 군단  후기 로마군\n로마 군단 목록\n \n로마 제국 말기에, 군단의 수는 늘어났고 로마...
# 231    버트런드 러셀  러셀은 1890년 케임브리지 대학교의 트리니티 칼리지에 장학생으로 들어갔다. 그는 ...
# ...

# %% [markdown]
# ### 5-2. context 중복

# %%
preprocessed_train_df[preprocessed_train_df.duplicated(['context'],keep=False)].sort_values('context')
# Out:
#             title                                            context  \
# 2181         시간이동  "시간이동"은 미국의 방송사 ABC의 텔레비전 드라마 시리즈 로스트의 시즌 프리미어...
# 2164         시간이동  "시간이동"은 미국의 방송사 ABC의 텔레비전 드라마 시리즈 로스트의 시즌 프리미어...
# 3408  히이라기자와 에리오르  '사쿠라 카드 편'에서부터 등장하는 인물로 종종 알 수 없는 웃음과 아이답지 않은 ...
# 1350  히이라기자와 에리오르  '사쿠라 카드 편'에서부터 등장하는 인물로 종종 알 수 없는 웃음과 아이답지 않은 ...
# 2353      하인리히 4세  1090년 교황 우르바노 2세의 주선으로 43세의 토스카나 여후작 마틸다가 결혼을 ...
# ...           ...                                                ...
# 1946          탐무즈  활달한 대지의 여신 이슈타르-인니나(이하 이슈타르)가 식물과 생명의 성장의 신인 자...
# 2743         효문태후  효문태후 박씨(孝文太后 薄氏, ? ~ 기원전 155년)는 전한 고제 유방의 후궁 중...
# 2684         효문태후  효문태후 박씨(孝文太后 薄氏, ? ~ 기원전 155년)는 전한 고제 유방의 후궁 중...
# 1449            힐  힐은 전쟁중에 논쟁을 피하지 못했다. 병약한 체질이라서 여러 번 병치레를 했기에, ...
# 389             힐  힐은 전쟁중에 논쟁을 피하지 못했다. 병약한 체질이라서 여러 번 병치레를 했기에, ...
#
#       context_length                                          question  \
# ...

# %%
preprocessed_valid_df[preprocessed_valid_df.duplicated(['context'],keep=False)].sort_values('context')
# Out:
#        title                                            context  \
# 74   버트런드 러셀  러셀은 1890년 케임브리지 대학교의 트리니티 칼리지에 장학생으로 들어갔다. 그는 ...
# 231  버트런드 러셀  러셀은 1890년 케임브리지 대학교의 트리니티 칼리지에 장학생으로 들어갔다. 그는 ...
# 6        자수장  수를 놓을 때에 사용하는 기법을 문양의 형태에 따라 나누어 보면 선을 잇는 수, 면...
# 81       자수장  수를 놓을 때에 사용하는 기법을 문양의 형태에 따라 나누어 보면 선을 잇는 수, 면...
# 129      송나라  요나라와의 전연의 맹세에 지불한 것으로 알려진 재물은 비단 20만필, 은 10만량이...
# 205      송나라  요나라와의 전연의 맹세에 지불한 것으로 알려진 재물은 비단 20만필, 은 10만량이...
# 162    태양권계면  태양권계면(Heliopause)은 천문학에서 태양의 태양풍을 성간매질이 멈추게 하는...
# 189    태양권계면  태양권계면(Heliopause)은 천문학에서 태양의 태양풍을 성간매질이 멈추게 하는...
# 73        티칼  현재 우리가 볼 수 있는 티칼의 모습은 펜실베이니아 대학교와 과테말라 정부의 협조 ...
# 236       티칼  현재 우리가 볼 수 있는 티칼의 모습은 펜실베이니아 대학교와 과테말라 정부의 협조 ...
#
#      context_length                                question  question_length  \
# 74              667                         러셀의 여자 친구의 종교는?               15
# 231             667       러셀은 누구의 가족과 함께 1889년 파리 박람회에 갔는가?               33
# ...

# %% [markdown]
# ### 5-3. question 중복

# %%
preprocessed_train_df[preprocessed_train_df.duplicated(['question'],keep=False)].sort_values('question')
# Out:
# Empty DataFrame
# Columns: [title, context, context_length, question, question_length, answer, answer_start, answer_length, document_id, __index_level_0__]
# Index: []

# %%
preprocessed_valid_df[preprocessed_valid_df.duplicated(['question'],keep=False)].sort_values('question')
# Out:
# Empty DataFrame
# Columns: [title, context, context_length, question, question_length, answer, answer_start, answer_length, document_id, __index_level_0__]
# Index: []

# %% [markdown]
# ### 5-4. answer 중복

# %%
preprocessed_train_df[preprocessed_train_df.duplicated(['answer'],keep=False)].sort_values('answer')
# Out:
#                       title  \
# 534                   팔라 제국
# 806                  하워드 마셜
# 3831             교황 우르바노 5세
# 3181             교황 우르바노 5세
# 2859            모르겐슈테른 (무기)
# ...                     ...
# 110                   빌 클린턴
# 3219                 크레시 전투
# 3891  팔레올로고스 왕조 치하의 비잔티움 제국
# 1164    1980년 일본 프로 야구 올스타전
# 247     1987년 일본 프로 야구 올스타전
#
#                                                 context  context_length  \
# 534   데바팔라 사후 팔라 제국은 점차 힘을 잃기 시작하였다. 데바팔라의 조카였던 비그라하...             647
# 806   그는 구두로는 안나 니콜 스미스에게 자신의 재산의 반을 주겠다고 약속했다 하나 유언...             619
# 3831  우르바노 5세 치세의 큰 특징으로는 로마로 귀환하려고 노력한 점과 로마에 대한 세속...            1521
# 3181  우르바노 5세 치세의 큰 특징으로는 로마로 귀환하려고 노력한 점과 로마에 대한 세속...            1521
# 2859  모르겐슈테른(Morgenstern금성)은 중세 시대 무기의 하나이다. 영어명인 모닝...            1020
# ...                                                 ...             ...
# 110   클린턴의 첫 기간의 말기가 접근하면서 새로운 스캔들이 일어났다. 스캔들은 클린턴과 ...             624
# ...

# %%
preprocessed_valid_df[preprocessed_valid_df.duplicated(['answer'],keep=False)].sort_values('answer')
# Out:
# Empty DataFrame
# Columns: [title, context, context_length, question, question_length, answer, answer_start, answer_length, document_id, __index_level_0__]
# Index: []

# %% [markdown]
# ## 6. 복합 중복 데이터 찾기

# %% [markdown]
# ### 6-1. 모든 것이 중복인 것 -> 삭제 대상

# %%
preprocessed_train_df[preprocessed_train_df.duplicated(['title','context','context_length','question','question_length','answer','answer_start','answer_length','document_id','__index_level_0__'],keep=False)].sort_values('answer')
# Out:
# Empty DataFrame
# Columns: [title, context, context_length, question, question_length, answer, answer_start, answer_length, document_id, __index_level_0__]
# Index: []

# %%
preprocessed_valid_df[preprocessed_valid_df.duplicated(['title','context','context_length','question','question_length','answer','answer_start','answer_length','document_id','__index_level_0__'],keep=False)].sort_values('answer')
# Out:
# Empty DataFrame
# Columns: [title, context, context_length, question, question_length, answer, answer_start, answer_length, document_id, __index_level_0__]
# Index: []

# %% [markdown]
# ### 6-2. 모두 중복이지만 답변이 다른 것 -> 다중 정답
# - 없음 (질문 중복이 없으므로)

# %% [markdown]
# ### 6-3. 모두 중복이지만 answer start가 다른 것 -> 정답의 위치가 여러 곳
# - 없음(질문 중복이 없으므로)

# %% [markdown]
# ### 6-4. 모두 중복이지만 context가 다른 것 -> 동일한 답을 구할 수 있는 문장
# - 없음(질문 중복이 없으므로)

# %% [markdown]
# ### 6-5. 질문만 다르고 문장과 답변이 같은 것 -> 질문의 의미가 동일한 것

# %%
preprocessed_train_df[preprocessed_train_df.duplicated(['title','context','context_length','answer','answer_start','answer_length'],keep=False)].sort_values('answer')
# Out:
#                      title                                            context  \
# 3831            교황 우르바노 5세  우르바노 5세 치세의 큰 특징으로는 로마로 귀환하려고 노력한 점과 로마에 대한 세속...
# 3181            교황 우르바노 5세  우르바노 5세 치세의 큰 특징으로는 로마로 귀환하려고 노력한 점과 로마에 대한 세속...
# 1862               베트남의 역사  베트남 전쟁\n\n 베트남 전쟁은 1964년 통킹만 사건을 구실로 미국이 북 베트남...
# 2805               베트남의 역사  베트남 전쟁\n\n 베트남 전쟁은 1964년 통킹만 사건을 구실로 미국이 북 베트남...
# 3205        2015년 네팔 봉쇄 사태  2015년 9월 20일에는 계속 정체중이였던 네팔의 헌법 수립안이 네팔 의회에서 9...
# 2001        2015년 네팔 봉쇄 사태  2015년 9월 20일에는 계속 정체중이였던 네팔의 헌법 수립안이 네팔 의회에서 9...
# 2756                   조혜련  조혜련은 일본 버라이어티 프로그램에 출연해서 한국을 비하하는 듯한 제반 발언과, 쇼...
# 2702                   조혜련  조혜련은 일본 버라이어티 프로그램에 출연해서 한국을 비하하는 듯한 제반 발언과, 쇼...
# 3714              단순포진 각막염  단순포진 각막염(Herpetic simplex keratitis)은 단순포진바이러스...
# 503               단순포진 각막염  단순포진 각막염(Herpetic simplex keratitis)은 단순포진바이러스...
# 256                    차사백  일본 오사카시의 람버트 여학원 보육전수부를 졸업하고, 1923년부터 서울의 중앙보육...
# ...

# %%
preprocessed_valid_df[preprocessed_valid_df.duplicated(['title','context','context_length','answer','answer_start','answer_length'],keep=False)].sort_values('answer')
# Out:
# Empty DataFrame
# Columns: [title, context, context_length, question, question_length, answer, answer_start, answer_length, document_id, __index_level_0__]
# Index: []

# %% [markdown]
# ### 7-1. document_id는 어떤 의미를 가질까?

# %% [markdown]
# ### 7-2. __index_level_0__은 어떤 의미를 가질까?
